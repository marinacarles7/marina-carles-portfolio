# %%
# !pip install google-genai

# %%
from google import genai

# %%
gemini_api = "AIzaSyBULTK97tLyfJQLMb7qHzgk1TpvtqvquHI" # replace with your API key
client = genai.Client(api_key = gemini_api)

# %%
prompt = "Write one concise email for me to politely refuse a student who asks for homework extension and explain why."

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",   # or another currently supported model
    contents=prompt,
)

print(response.text)
# Out:
# Subject: Re: Homework Extension Request - [Student's Name] - [Assignment Name]
#
# Dear [Student Name],
#
# Thank you for reaching out regarding an extension for [Assignment Name].
#
# Unfortunately, I am unable to grant extensions for assignments. My policy is to maintain consistent deadlines for all students to ensure fairness and help everyone manage the course workload effectively.
#
# Please refer to the syllabus for information on the late submission policy.
#
# Sincerely,
#
# [Your Name]

# %%
print(response.usage_metadata)
# Out:
# cache_tokens_details=None cached_content_token_count=None candidates_token_count=95 candidates_tokens_details=None prompt_token_count=21 prompt_tokens_details=[ModalityTokenCount(
#   modality=<MediaModality.TEXT: 'TEXT'>,
#   token_count=21
# )] thoughts_token_count=1076 tool_use_prompt_token_count=None tool_use_prompt_tokens_details=None total_token_count=1192 traffic_type=None

# %%
print(response.text)
# Out:
# Subject: Re: Homework Extension Request - [Student's Name] - [Assignment Name]
#
# Dear [Student Name],
#
# Thank you for reaching out regarding an extension for [Assignment Name].
#
# Unfortunately, I am unable to grant extensions for assignments. My policy is to maintain consistent deadlines for all students to ensure fairness and help everyone manage the course workload effectively.
#
# Please refer to the syllabus for information on the late submission policy.
#
# Sincerely,
#
# [Your Name]

# %%
from google import genai
